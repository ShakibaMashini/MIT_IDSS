# %% [markdown]
# <a href="https://colab.research.google.com/github/ShakibaMashini/MIT_IDSS/blob/main/hotel_bookin_cancellation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project - Classification and Hypothesis Testing: Hotel Booking Cancellation Prediction**
#
# ## **Marks: 40**
#
# ---------------
# ## **Problem Statement**
#
# ### **Context**
#
# **A significant number of hotel bookings are called off due to cancellations or no-shows.** Typical reasons for cancellations include change of plans, scheduling conflicts, etc. This is often made easier by the option to do so free of charge or preferably at a low cost. This may be beneficial to hotel guests, but it is a less desirable and possibly revenue-diminishing factor for hotels to deal with. Such losses are particularly high on last-minute cancellations.
#
# The new technologies involving online booking channels have dramatically changed customers’ booking possibilities and behavior. This adds a further dimension to the challenge of how hotels handle cancellations, which are no longer limited to traditional booking and guest characteristics.
#
# This pattern of cancellations of bookings impacts a hotel on various fronts:
# 1. **Loss of resources (revenue)** when the hotel cannot resell the room.
# 2. **Additional costs of distribution channels** by increasing commissions or paying for publicity to help sell these rooms.
# 3. **Lowering prices last minute**, so the hotel can resell a room, resulting in reducing the profit margin.
# 4. **Human resources to make arrangements** for the guests.
#
# ### **Objective**
#
# This increasing number of cancellations calls for a Machine Learning based solution that can help in predicting which booking is likely to be canceled. INN Hotels Group has a chain of hotels in Portugal - they are facing problems with this high number of booking cancellations and have reached out to your firm for data-driven solutions. You, as a Data Scientist, have to analyze the data provided to find which factors have a high influence on booking cancellations, build a predictive model that can predict which booking is going to be canceled in advance, and help in formulating profitable policies for cancellations and refunds.
#
#
# ### **Data Description**
#
# The data contains the different attributes of customers' booking details. The detailed data dictionary is given below:
#
#
# **Data Dictionary**
#
# * **Booking_ID:** Unique identifier of each booking
# * **no_of_adults:** Number of adults
# * **no_of_children:** Number of children
# * **no_of_weekend_nights:** Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel
# * **no_of_week_nights:** Number of weekday nights (Monday to Friday) the guest stayed or booked to stay at the hotel
# * **type_of_meal_plan:** Type of meal plan booked by the customer:
#     * Not Selected – No meal plan selected
#     * Meal Plan 1 – Breakfast
#     * Meal Plan 2 – Half board (breakfast and one other meal)
#     * Meal Plan 3 – Full board (breakfast, lunch, and dinner)
# * **required_car_parking_space:** Does the customer require a car parking space? (0 - No, 1- Yes)
# * **room_type_reserved:** Type of room reserved by the customer. The values are ciphered (encoded) by INN Hotels.
# * **lead_time:** Number of days between the date of booking and the arrival date
# * **arrival_year:** Year of arrival date
# * **arrival_month:** Month of arrival date
# * **arrival_date:** Date of the month
# * **market_segment_type:** Market segment designation.
# * **repeated_guest:** Is the customer a repeated guest? (0 - No, 1- Yes)
# * **no_of_previous_cancellations:** Number of previous bookings that were canceled by the customer prior to the current booking
# * **no_of_previous_bookings_not_canceled:** Number of previous bookings not canceled by the customer prior to the current booking
# * **avg_price_per_room:** Average price per day of the reservation; prices of the rooms are dynamic. (in euros)
# * **no_of_special_requests:** Total number of special requests made by the customer (e.g. high floor, view from the room, etc)
# * **booking_status:** Flag indicating if the booking was canceled or not.

# %% [markdown]
# ## **Importing the libraries required**

# %%
# Importing the basic libraries we will require for the project

# Libraries to help with reading and manipulating data
import pandas as pd
import numpy as np

# Libaries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# Importing the Machine Learning models we require from Scikit-Learn
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier

# Importing the other functions we may require from Scikit-Learn
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler, LabelEncoder, OneHotEncoder

# To get diferent metric scores
from sklearn.metrics import confusion_matrix,classification_report,roc_auc_score,precision_recall_curve,roc_curve,make_scorer

# Code to ignore warnings from function usage
import warnings;
import numpy as np
warnings.filterwarnings('ignore')

# %% [markdown]
# ## **Loading the dataset**

# %%
hotel = pd.read_csv("INNHotelsGroup.csv")

# %%
# Copying data to another variable to avoid any changes to original data
data = hotel.copy()

# %% [markdown]
# ## **Overview of the dataset**

# %% [markdown]
# ### **View the first and last 5 rows of the dataset**
#
# Let's **view the first few rows and last few rows** of the dataset in order to understand its structure a little better.
#
# We will use the head() and tail() methods from Pandas to do this.

# %%
data.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        224          2017             10             2
# ...

# %%
data.tail()
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 36270                  6       Meal Plan 1                           0
# 36271                  3       Meal Plan 1                           0
# 36272                  6       Meal Plan 1                           0
# 36273                  3      Not Selected                           0
# 36274                  2       Meal Plan 1                           0
#
#       room_type_reserved  lead_time  arrival_year  arrival_month  \
# ...

# %% [markdown]
# ### **Understand the shape of the dataset**

# %%
data.shape
# Out:
# (36275, 19)

# %% [markdown]
# * The dataset has 36275 rows and 19 columns.

# %% [markdown]
# ### **Check the data types of the columns for the dataset**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Booking_ID                            36275 non-null  object
#  1   no_of_adults                          36275 non-null  int64
#  2   no_of_children                        36275 non-null  int64
#  3   no_of_weekend_nights                  36275 non-null  int64
#  4   no_of_week_nights                     36275 non-null  int64
#  5   type_of_meal_plan                     36275 non-null  object
#  6   required_car_parking_space            36275 non-null  int64
#  7   room_type_reserved                    36275 non-null  object
#  8   lead_time                             36275 non-null  int64
#  9   arrival_year                          36275 non-null  int64
#  10  arrival_month                         36275 non-null  int64
# ...

# %% [markdown]
# * `Booking_ID`, `type_of_meal_plan`, `room_type_reserved`, `market_segment_type`, and `booking_status` are of object type while rest columns are numeric in nature.
#
# * There are no null values in the dataset.

# %% [markdown]
# ### **Dropping duplicate values**

# %%
# checking for duplicate values
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - There are **no duplicate values** in the data.

# %% [markdown]
# ### **Dropping the unique values column**

# %% [markdown]
# **Let's drop the Booking_ID column first before we proceed forward**, as a column with unique values will have almost no predictive power for the Machine Learning problem at hand.

# %%
data = data.drop(["Booking_ID"], axis=1)

# %%
data.head()
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             2               0                     1                  2
# 1             2               0                     2                  3
# 2             1               0                     2                  1
# 3             2               0                     0                  2
# 4             2               0                     1                  1
#
#   type_of_meal_plan  required_car_parking_space room_type_reserved  lead_time  \
# 0       Meal Plan 1                           0        Room_Type 1        224
# 1      Not Selected                           0        Room_Type 1          5
# 2       Meal Plan 1                           0        Room_Type 1          1
# 3       Meal Plan 1                           0        Room_Type 1        211
# 4      Not Selected                           0        Room_Type 1         48
#
# ...

# %%
print(0 in data['no_of_adults'].unique())
# Out:
# True

# %% [markdown]
# ### **Question 1: Check the summary statistics of the dataset and write your observations (2 Marks)**

# %% [markdown]
# **Let's check the statistical summary of the data.**

# %%
# Remove _________ and complete the code
data.describe()
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# count  36275.000000    36275.000000          36275.000000       36275.000000
# mean       1.844962        0.105279              0.810724           2.204300
# std        0.518715        0.402648              0.870644           1.410905
# min        0.000000        0.000000              0.000000           0.000000
# 25%        2.000000        0.000000              0.000000           1.000000
# 50%        2.000000        0.000000              1.000000           2.000000
# 75%        2.000000        0.000000              2.000000           3.000000
# max        4.000000       10.000000              7.000000          17.000000
#
#        required_car_parking_space     lead_time  arrival_year  arrival_month  \
# count                36275.000000  36275.000000  36275.000000   36275.000000
# mean                     0.030986     85.232557   2017.820427       7.423653
# ...

# %% [markdown]
# **Write your answers here:
# the number of adults column has a min of 0, a max of 4, and a standard deviation of less than 1/3 the mean. In column 'no_of_adults,' there is a value of 0. It is not possible to place an order with 0 adults.
# The lead time column has a min of 0, a max of 443, and a standard deviation equal to or greater than the mean. treating arrival year, month, and day as continuous variables is inappropriate. For instance, a mean arrival year of 2017.82 would indicate to me that the average date of hotel bookings was around October 26, 2017

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# ### **Question 2: Univariate Analysis**

# %% [markdown]
# Let's explore these variables in some more depth by observing their distributions.

# %% [markdown]
# We will first define a **hist_box() function** that provides both a boxplot and a histogram in the same visual, with which we can perform univariate analysis on the columns of this dataset.

# %%
# Defining the hist_box() function
def hist_box(data,col):
  f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={'height_ratios': (0.15, 0.85)}, figsize=(12,6))
  # Adding a graph in each part
  sns.boxplot(data[col], ax=ax_box, showmeans=True)
  sns.distplot(data[col], ax=ax_hist)
  plt.show()

# %% [markdown]
# #### **Question 2.1:  Plot the histogram and box plot for the variable `Lead Time` using the hist_box function provided and write your insights. (1 Mark)**

# %%
# Remove _________ and complete the code
hist_box(data,'lead_time')

# %% [markdown]
# **Write your answers here:_____**

# %% [markdown]
# The lead_time data is heavily right-skewed as determined by the general shape of the histogram, the presence of several outliers on the box plot extending far past the upper limit of the interquartile range, and the location of the mean value to the right of the median value on the boxplot. Approximately 50% of reservations are made with between ~10 and 300 days of lead time (large spread)

# %% [markdown]
# #### **Question 2.2:  Plot the histogram and box plot for the variable `Average Price per Room` using the hist_box function provided and write your insights. (1 Mark)**

# %%
# Remove _________ and complete the code
hist_box(data,'avg_price_per_room')

# %% [markdown]
# **Write your answers here:_____**

# %% [markdown]
# The data in avg_price_per_room is pretty centered around an average price per room of ~100 Euros but does show signs of both right and left skew, with the magnitude of the right skew overcoming the minor effect of the left skew, as evidenced by the mean value being more significant than the median.

# %% [markdown]
# **Interestingly some rooms have a price equal to 0. Let's check them.**

# %%
data[data["avg_price_per_room"] == 0]
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 63                1               0                     0                  1
# 145               1               0                     0                  2
# 209               1               0                     0                  0
# 266               1               0                     0                  2
# 267               1               0                     2                  1
# ...             ...             ...                   ...                ...
# 35983             1               0                     0                  1
# 36080             1               0                     1                  1
# 36114             1               0                     0                  1
# 36217             2               0                     2                  1
# 36250             1               0                     0                  2
#
# ...

# %% [markdown]
# - There are quite a few hotel rooms which have a price equal to 0.
# - In the market segment column, it looks like many values are complementary.

# %%
data.loc[data["avg_price_per_room"] == 0, "market_segment_type"].value_counts()
# Out:
# Complementary    354
# Online           191
# Name: market_segment_type, dtype: int64

# %% [markdown]
# * It makes sense that most values with room prices equal to 0 are the rooms given as complimentary service from the hotel.
# * The rooms booked online must be a part of some promotional campaign done by the hotel.

# %%
# Calculating the 25th quantile
Q1 = data["avg_price_per_room"].quantile(0.25)

# Calculating the 75th quantile
Q3 = data["avg_price_per_room"].quantile(0.75)

# Calculating IQR
IQR = Q3 - Q1

# Calculating value of upper whisker
Upper_Whisker = Q3 + 1.5 * IQR
Upper_Whisker
# Out:
# 179.55

# %%
# assigning the outliers the value of upper whisker
data.loc[data["avg_price_per_room"] >= 500, "avg_price_per_room"] = Upper_Whisker

# %% [markdown]
# #### **Let's understand the distribution of the categorical variables**

# %% [markdown]
# **Number of Children**

# %%
sns.countplot(data['no_of_children'])
plt.show()

# %%
data['no_of_children'].value_counts(normalize=True)
# Out:
# 0     0.925624
# 1     0.044604
# 2     0.029166
# 3     0.000524
# 9     0.000055
# 10    0.000028
# Name: no_of_children, dtype: float64

# %% [markdown]
# * Customers were not travelling with children in 93% of cases.
# * There are some values in the data where the number of children is 9 or 10, which is highly unlikely.
# * We will replace these values with the maximum value of 3 children.

# %%
# replacing 9, and 10 children with 3
data["no_of_children"] = data["no_of_children"].replace([9, 10], 3)

# %% [markdown]
# **Arrival Month**

# %%
sns.countplot(data["arrival_month"])
plt.show()

# %%
data['arrival_month'].value_counts(normalize=True)
# Out:
# 10    0.146575
# 9     0.127112
# 8     0.105114
# 6     0.088298
# 12    0.083280
# 11    0.082150
# 7     0.080496
# 4     0.075424
# 5     0.071620
# 3     0.065003
# 2     0.046975
# 1     0.027953
# Name: arrival_month, dtype: float64

# %% [markdown]
# * October is the busiest month for hotel arrivals followed by September and August. **Over 35% of all bookings**, as we see in the above table, were for one of these three months.
# * Around 14.7% of the bookings were made for an October arrival.

# %% [markdown]
# **Booking Status**

# %%
sns.countplot(data["booking_status"])
plt.show()

# %%
data['booking_status'].value_counts(normalize=True)
# Out:
# Not_Canceled    0.672364
# Canceled        0.327636
# Name: booking_status, dtype: float64

# %% [markdown]
# * 32.8% of the bookings were canceled by the customers.

# %% [markdown]
# **Let's encode Canceled bookings to 1 and Not_Canceled as 0 for further analysis**

# %%
data["booking_status"] = data["booking_status"].apply(
    lambda x: 1 if x == "Canceled" else 0
)

# %% [markdown]
# ### **Question 3: Bivariate Analysis**

# %% [markdown]
# #### **Question 3.1: Find and visualize the correlation matrix using a heatmap and write your observations from the plot. (2 Marks)**

# %%
# Remove _________ and complete the code
cols_list = data.select_dtypes(include=np.number).columns.tolist()

plt.figure(figsize=(12, 7))
sns.heatmap(data[cols_list].corr())
plt.show()

# %% [markdown]
# **Write your answers here:_____**

# %% [markdown]
# Whether or not the guest was a repeated guest or had previously booked room(s) with the hotel seems to be relatively strongly correlated with the number of previous cancellations and several previous bookings not canceled (which makes sense as a non-repeat guest will not have any cancellation or fulfillment history). Otherwise, the average price per room correlates somewhat with the number of adults and children or, more generally, the overall number of guests associated with each booking and the year the booking was made. The lead time of the booking also correlates with the booking status.

# %% [markdown]
# **Hotel rates are dynamic and change according to demand and customer demographics. Let's see how prices vary across different market segments**

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(
    data=data, x="market_segment_type", y="avg_price_per_room", palette="gist_rainbow"
)
plt.show()

# %% [markdown]
# * Rooms booked online have high variations in prices.
# * The offline and corporate room prices are almost similar.
# * Complementary market segment gets the rooms at very low prices, which makes sense.

# %% [markdown]
# We will define a **stacked barplot()** function to help analyse how the target variable varies across predictor categories.

# %%
# Defining the stacked_barplot() function
def stacked_barplot(data,predictor,target,figsize=(10,6)):
  (pd.crosstab(data[predictor],data[target],normalize='index')*100).plot(kind='bar',figsize=figsize,stacked=True)
  plt.legend(loc="lower right")
  plt.ylabel('Percentage Cancellations %')

# %% [markdown]
# #### **Question 3.2: Plot the stacked barplot for the variable `Market Segment Type` against the target variable `Booking Status` using the stacked_barplot  function provided and write your insights. (1 Mark)**

# %%
# Remove _________ and complete the code
stacked_barplot(data, 'market_segment_type', 'booking_status')

# %% [markdown]
# **Write your answers here:_____**

# %% [markdown]
# Complementary and corporate market segment type booking had the highest rates of fulfillment (lowest occurrence of cancellation), while online and aviation market segment types had the highest incidence of canceled bookings (lowest fulfillment)

# %% [markdown]
# #### **Question 3.3: Plot the stacked barplot for the variable `Repeated Guest` against the target variable `Booking Status` using the stacked_barplot  function provided and write your insights. (1 Mark)**
#
# Repeating guests are the guests who stay in the hotel often and are important to brand equity.

# %%
# Remove _________ and complete the code
stacked_barplot(data, 'repeated_guest', 'booking_status')

# %% [markdown]
# **Write your answers here:_____**

# %% [markdown]
# Repeat guests, or guests who have stayed with the hotel
# before, had fewer cancellations (higher fulfillment rate) than bookings made by guests
# who had no prior booking history with the hotel.

# %% [markdown]
# **Let's analyze the customer who stayed for at least a day at the hotel.**

# %%
stay_data = data[(data["no_of_week_nights"] > 0) & (data["no_of_weekend_nights"] > 0)]
stay_data["total_days"] = (stay_data["no_of_week_nights"] + stay_data["no_of_weekend_nights"])

stacked_barplot(stay_data, "total_days", "booking_status",figsize=(15,6))

# %% [markdown]
# * The general trend is that the chances of cancellation increase as the number of days the customer planned to stay at the hotel increases.

# %% [markdown]
# **As hotel room prices are dynamic, Let's see how the prices vary across different months**

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(y=data["avg_price_per_room"], x=data["arrival_month"], ci=None)
plt.show()

# %% [markdown]
# * The price of rooms is highest in May to September - around 115 euros per room.

# %% [markdown]
# ## **Data Preparation for Modeling**
#
# - We want to predict which bookings will be canceled.
# - Before we proceed to build a model, we'll have to encode categorical features.
# - We'll split the data into train and test to be able to evaluate the model that we build on the train data.

# %% [markdown]
# **Separating the independent variables (X) and the dependent variable (Y)**

# %%
X = data.drop(["booking_status"], axis=1)
Y = data["booking_status"]

X = pd.get_dummies(X, drop_first=True) # Encoding the Categorical features

# %% [markdown]
# **Splitting the data into a 70% train and 30% test set**
#
# Some classification problems can exhibit a large imbalance in the distribution of the target classes: for instance there could be several times more negative samples than positive samples. In such cases it is recommended to use the **stratified sampling** technique to ensure that relative class frequencies are approximately preserved in each train and validation fold.

# %%
# Splitting data in train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.30,stratify=Y, random_state=1)

# %%
print("Shape of Training set : ", X_train.shape)
print("Shape of test set : ", X_test.shape)
print("Percentage of classes in training set:")
print(y_train.value_counts(normalize=True))
print("Percentage of classes in test set:")
print(y_test.value_counts(normalize=True))
# Out:
# Shape of Training set :  (25392, 27)
# Shape of test set :  (10883, 27)
# Percentage of classes in training set:
# 0    0.672377
# 1    0.327623
# Name: booking_status, dtype: float64
# Percentage of classes in test set:
# 0    0.672333
# 1    0.327667
# Name: booking_status, dtype: float64

# %% [markdown]
# ## **Model Evaluation Criterion**
#
# #### **Model can make wrong predictions as:**
#
# 1. Predicting a customer will not cancel their booking but in reality, the customer will cancel their booking.
# 2. Predicting a customer will cancel their booking but in reality, the customer will not cancel their booking.
#
# #### **Which case is more important?**
#
# Both the cases are important as:
#
# * If we predict that a booking will not be canceled and the booking gets canceled then the hotel will lose resources and will have to bear additional costs of distribution channels.
#
# * If we predict that a booking will get canceled and the booking doesn't get canceled the hotel might not be able to provide satisfactory services to the customer by assuming that this booking will be canceled. This might damage brand equity.
#
#
#
# #### **How to reduce the losses?**
#
# * The hotel would want the `F1 Score` to be maximized, the greater the F1  score, the higher the chances of minimizing False Negatives and False Positives.

# %% [markdown]
# **Also, let's create a function to calculate and print the classification report and confusion matrix so that we don't have to rewrite the same code repeatedly for each model.**

# %%
# Creating metric function
def metrics_score(actual, predicted):
    print(classification_report(actual, predicted))

    cm = confusion_matrix(actual, predicted)
    plt.figure(figsize=(8,5))

    sns.heatmap(cm, annot=True,  fmt='.2f', xticklabels=['Not Cancelled', 'Cancelled'], yticklabels=['Not Cancelled', 'Cancelled'])
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show()

# %% [markdown]
# ## **Building the model**
#
# We will be building 4 different models:
#
# - **Logistic Regression**
# - **Support Vector Machine (SVM)**
# - **Decision Tree**
# - **Random Forest**

# %% [markdown]
# ### **Question 4: Logistic Regression (6 Marks)**

# %% [markdown]
# #### **Question 4.1: Build a Logistic Regression model (Use the sklearn library) (1 Mark)**

# %%
# Remove _________ and complete the code

# Fitting logistic regression model
lg=LogisticRegression()
lg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# #### **Question 4.2: Check the performance of the model on train and test data (2 Marks)**

# %%
# Remove _________ and complete the code

# Checking the performance on the training data
y_pred_train = lg.predict(X_train)
metrics_score(y_train, y_pred_train)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86     17073
#            1       0.74      0.60      0.67      8319
#
#     accuracy                           0.80     25392
#    macro avg       0.78      0.75      0.76     25392
# weighted avg       0.80      0.80      0.79     25392

# %% [markdown]
# **Write your Answer here:**

# %% [markdown]
# The model better predicts 'Not Cancelled' bookings than 'Cancelled' bookings, as evidenced by the higher precision, recall, and f-stat values associated with the 'Not Cancelled' (0) than 'Cancelled' (1) lines of the table. Since both false negatives (failing to predict a canceled booking) and false positives (incorrectly predicting a booking will be canceled) are both potentially costly to the hotel, maximizing all three metrics for each case is advantageous instead of relying on average values for the model assessment.

# %% [markdown]
# Let's check the performance on the test set

# %%
# Remove _________ and complete the code

# Checking the performance on the test dataset
y_pred_test = lg.predict(X_test)
metrics_score(y_test, y_pred_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.85      7317
#            1       0.73      0.59      0.65      3566
#
#     accuracy                           0.79     10883
#    macro avg       0.77      0.74      0.75     10883
# weighted avg       0.79      0.79      0.79     10883

# %% [markdown]
# **Write your Answer here:**

# %% [markdown]
#  The model performs similarly on the test data as on the training data, tending to predict better the 'Not Cancelled' bookings than the 'Cancelled' bookings. Precision, recall, and f-stat values for the test data are very close to those produced by the training data indicating that the model is not overfitting.

# %% [markdown]
# #### **Question 4.3: Find the optimal threshold for the model using the Precision-Recall Curve. (1 Mark)**
#
# Precision-Recall curves summarize the trade-off between the true positive rate and the positive predictive value for a predictive model using different probability thresholds.
#
# Let's use the Precision-Recall curve and see if we can find a **better threshold.**

# %%
# Remove _________ and complete the code

# Predict_proba gives the probability of each observation belonging to each class
y_scores_lg=lg.predict_proba(X_train)


precisions_lg, recalls_lg, thresholds_lg = precision_recall_curve(y_train, y_scores_lg[:,1])

# Plot values of precisions, recalls, and thresholds
plt.figure(figsize=(10,7))
plt.plot(thresholds_lg, precisions_lg[:-1], 'b--', label='precision')
plt.plot(thresholds_lg, recalls_lg[:-1], 'g--', label = 'recall')
plt.xlabel('Threshold')
plt.legend(loc='upper left')
plt.ylim([0,1])
plt.show()

# %% [markdown]
# **Write your answers here:_____**

# %% [markdown]
# Precision and recall are balanced at a threshold of approximately 0.41

# %%
# Setting the optimal threshold
optimal_threshold = 0.41

# %% [markdown]
# #### **Question 4.4: Check the performance of the model on train and test data using the optimal threshold. (2 Marks)**

# %%
# Remove _________ and complete the code

# Creating confusion matrix
y_pred_train = lg.predict_proba(X_train)
metrics_score(y_train, y_pred_train[:,1]>optimal_threshold)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.84      0.84     17073
#            1       0.68      0.69      0.69      8319
#
#     accuracy                           0.79     25392
#    macro avg       0.76      0.77      0.76     25392
# weighted avg       0.79      0.79      0.79     25392

# %% [markdown]
# **Write your answers here:_____**

# %% [markdown]
# Adjusting the threshold resulted in higher precision, lower recall, and lower f-stat on the 'Not Cancelled' predictive power and decreased the precision, increased the recall and increased the f-stat of the 'Cancelled' predictive power. The 'Not Cancelled' metrics did not seem as sensitive to the threshold adjustment as the 'Cancelled' metrics. Overall, the average values for the model were not significantly changed, indicating increases in precision for a particular classification caused decreases in recall for that particular classification and vice versa.

# %% [markdown]
# Let's check the performance on the test set

# %%
# Remove _________ and complete the code

y_pred_test = lg.predict_proba(X_test)
metrics_score(y_test, y_pred_test[:,1]>optimal_threshold)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84      7317
#            1       0.67      0.68      0.67      3566
#
#     accuracy                           0.78     10883
#    macro avg       0.76      0.76      0.76     10883
# weighted avg       0.79      0.78      0.79     10883

# %% [markdown]
# **Write your answers here:_____**

# %% [markdown]
# The optimized threshold model fits the test data with similar overall accuracy to the fitment of the training data, indicating that the model is not overfitting. The optimized threshold fit to the test data has increased precision, decreased recall levels, and a decreased f-stat value for the 'Not Cancelled' classification compared to the non-optimized fit to the test data. The optimized model fit to the test data has decreased levels of precision, increased levels of recall, and an increased f-stat for the "Cancelled' classification when compared to the non-optimized model. Average values of fit metrics between optimized and non-optimized models indicate a re-shuffling of overall accuracy between classifications, i.e., increased accuracy in predicting 'Cancelled' bookings came to the expense of decreased overall accuracy in predicting 'Not Cancelled' bookings.

# %% [markdown]
# ### **Question 5: Support Vector Machines (11 Marks)**

# %% [markdown]
# To accelerate SVM training, let's scale the data for support vector machines.

# %%
scaling = MinMaxScaler(feature_range=(-1,1)).fit(X_train)
X_train_scaled = scaling.transform(X_train)
X_test_scaled = scaling.transform(X_test)

# %% [markdown]
# Let's build the models using the two of the widely used kernel functions:
#
# 1.   **Linear Kernel**
# 2.   **RBF Kernel**

# %% [markdown]
# #### **Question 5.1: Build a Support Vector Machine model using a linear kernel (1 Mark)**

# %% [markdown]
# **Note: Please use the scaled data for modeling Support Vector Machine**

# %%
# Remove _________ and complete the code

svm = SVC( kernel = 'linear' , probability = True) # Linear kernal or linear decision boundary
model = svm.fit(X_train_scaled , y_train)

# %% [markdown]
# #### **Question 5.2: Check the performance of the model on train and test data (2 Marks)**

# %%
# Remove _________ and complete the code

y_pred_train_svm = model.predict(X_train_scaled)
metrics_score(y_train , y_pred_train_svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86     17073
#            1       0.74      0.61      0.67      8319
#
#     accuracy                           0.80     25392
#    macro avg       0.79      0.76      0.77     25392
# weighted avg       0.80      0.80      0.80     25392

# %% [markdown]
# **Write your answers here:_____**

# %% [markdown]
# The linear SVM model fits the training data similarly to the Logistic model. The linear SVM model had a higher precision, recall, and f-stat for the 'Not-Cancelled' than the 'Cancelled' classification. The average values for fitment assessment were very similar to the logistic regression model values for the training data.

# %% [markdown]
# Checking model performance on test set

# %%
# Remove _________ and complete the code

y_pred_test_svm = model.predict(X_test_scaled)
metrics_score(y_test, y_pred_test_svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86      7317
#            1       0.74      0.61      0.67      3566
#
#     accuracy                           0.80     10883
#    macro avg       0.78      0.75      0.76     10883
# weighted avg       0.80      0.80      0.80     10883

# %% [markdown]
# **Write your answers here:_____**

# %% [markdown]
# The linear SVM model fits the test data with similar accuracy measures as the training data. Overall average accuracy metrics were similar to the training data fitment, and the general trend of better predicting the 'Not Cancelled' classification was maintained, indicating the model is not overfit.

# %% [markdown]
# #### **Question 5.3: Find the optimal threshold for the model using the Precision-Recall Curve. (1 Mark)**

# %%
# Remove _________ and complete the code

# Predict on train data
y_scores_svm=model.predict_proba(X_train_scaled)

precisions_svm, recalls_svm, thresholds_svm = precision_recall_curve(y_train, y_scores_svm[:,1])


# Plot values of precisions, recalls, and thresholds
plt.figure(figsize=(10,7))
plt.plot(thresholds_svm, precisions_svm[:-1], 'b--', label='precision')
plt.plot(thresholds_svm, recalls_svm[:-1], 'g--', label = 'recall')
plt.xlabel('Threshold')
plt.legend(loc='upper left')
plt.ylim([0,1])
plt.show()

# %% [markdown]
# **Write your answers here:_____**

# %% [markdown]
# Precision and recall are balanced at ~0.41

# %%
optimal_threshold_svm=0.41

# %% [markdown]
# #### **Question 5.4: Check the performance of the model on train and test data using the optimal threshold. (2 Marks)**

# %%
# Remove _________ and complete the code

y_pred_train_svm = model.predict(X_train_scaled)
metrics_score(y_train, y_pred_train_svm > optimal_threshold_svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86     17073
#            1       0.74      0.61      0.67      8319
#
#     accuracy                           0.80     25392
#    macro avg       0.79      0.76      0.77     25392
# weighted avg       0.80      0.80      0.80     25392

# %% [markdown]
# **Write your answers here:_____**

# %% [markdown]
#  Optimizing the threshold value did not affect the model fit to the training data.

# %%
# Remove _________ and complete the code
y_pred_test = model.predict(X_test_scaled)
metrics_score(y_test, y_pred_test > optimal_threshold_svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86      7317
#            1       0.74      0.61      0.67      3566
#
#     accuracy                           0.80     10883
#    macro avg       0.78      0.75      0.76     10883
# weighted avg       0.80      0.80      0.80     10883

# %% [markdown]
# **Write your answers here:_____**

# %% [markdown]
# Optimizing the threshold value did not affect the model fitment to the training or test data, indicating that the linear SVM, or SVM method in general, derives the optimal threshold during model building.

# %% [markdown]
# #### **Question 5.5: Build a Support Vector Machines model using an RBF kernel (1 Mark)**

# %%
# Remove _________ and complete the code

svm_rbf=SVC(kernel='rbf',probability=True)
svm_rbf.fit(X_train_scaled, y_train)
# Out:
# SVC(probability=True)

# %% [markdown]
# #### **Question 5.6: Check the performance of the model on train and test data (2 Marks)**

# %%
# Remove _________ and complete the code

y_pred_train_svm = svm_rbf.predict(X_train_scaled)
metrics_score(y_train, y_pred_train_svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.88     17073
#            1       0.79      0.65      0.71      8319
#
#     accuracy                           0.83     25392
#    macro avg       0.81      0.78      0.80     25392
# weighted avg       0.82      0.83      0.82     25392

# %% [markdown]
# **Write your answers here:_____**

# %% [markdown]
# The RBF kernel SVM had similar accuracy metrics to the linear SVM for the 'Not Cancelled' classification within the training data but had better metrics for the 'Cancelled' classification than the linear SVM. Overall average accuracy metrics were better for the RBF kernel model than the linear SVM model, likely due to the increased accuracy in predicting the 'Cancelled' classification.

# %% [markdown]
# #### Checking model performance on test set

# %%
# Remove _________ and complete the code

y_pred_test = svm_rbf.predict(X_test_scaled)
metrics_score(y_test, y_pred_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87      7317
#            1       0.78      0.63      0.70      3566
#
#     accuracy                           0.82     10883
#    macro avg       0.81      0.77      0.78     10883
# weighted avg       0.82      0.82      0.81     10883

# %% [markdown]
# **Write your answers here:_____**

# %% [markdown]
# The RBF kernel SVM fits the test data similarly to the training data, with similar accuracy metrics for each classification ('Cancelled' and 'Not Cancelled') as the training data and similar overall accuracy metrics, indicating the model is not overfit.

# %%
# Predict on train data
y_scores_svm=svm_rbf.predict_proba(X_train_scaled)

precisions_svm, recalls_svm, thresholds_svm = precision_recall_curve(y_train, y_scores_svm[:,1])

# Plot values of precisions, recalls, and thresholds
plt.figure(figsize=(10,7))
plt.plot(thresholds_svm, precisions_svm[:-1], 'b--', label='precision')
plt.plot(thresholds_svm, recalls_svm[:-1], 'g--', label = 'recall')
plt.xlabel('Threshold')
plt.legend(loc='upper left')
plt.ylim([0,1])
plt.show()

# %%
optimal_threshold_svm=0.4

# %% [markdown]
# #### **Question 5.7: Check the performance of the model on train and test data using the optimal threshold. (2 Marks)**

# %%
# Remove _________ and complete the code

y_pred_train_svm = svm_rbf.predict_proba(X_train_scaled)
metrics_score(y_train, y_pred_train_svm[:,1] > optimal_threshold_svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87     17073
#            1       0.73      0.74      0.73      8319
#
#     accuracy                           0.82     25392
#    macro avg       0.80      0.80      0.80     25392
# weighted avg       0.82      0.82      0.82     25392

# %% [markdown]
# **Write your answers here:_____**

# %% [markdown]
# The optimized threshold RBF kernel SVM has increased precision in predicting the 'Not Cancelled' (reduction in false positives) classification as well as an increased recall for the 'Cancelled' classification (reduction in false negatives) with similar if slightly increased average accuracy metrics over the non-optimized RBF Kernel SVM fit the training data.

# %%
# Remove _________ and complete the code

y_pred_test = svm_rbf.predict_proba(X_test_scaled)
metrics_score(y_test, y_pred_test[:,1] > optimal_threshold)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86      7317
#            1       0.72      0.72      0.72      3566
#
#     accuracy                           0.82     10883
#    macro avg       0.79      0.79      0.79     10883
# weighted avg       0.81      0.82      0.81     10883

# %% [markdown]
# **Write your answers here:_____**

# %% [markdown]
# The optimized threshold RBF Kernel SVM fit the test data with similar results to the training data, maintaining general trends and accuracy metrics for each classification as well as overall model metrics, and also displays similar improvements over the non-optimized fitment to the test data

# %% [markdown]
# ### **Question 6: Decision Trees (7 Marks)**

# %% [markdown]
# #### **Question 6.1: Build a Decision Tree Model (1 Mark)**

# %%
# Remove _________ and complete the code
cancel_probs=data.booking_status.value_counts(normalize=True)
model_dt = DecisionTreeClassifier(class_weight = {0: cancel_probs[0], 1: cancel_probs[1]}, random_state = 1)

model_dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight={0: 0.6723638869745003,
#                                      1: 0.32763611302549966},
#                        random_state=1)

# %% [markdown]
# #### **Question 6.2: Check the performance of the model on train and test data (2 Marks)**

# %%
# Remove _________ and complete the code

# Checking performance on the training dataset
pred_train_dt = model_dt.predict(X_train)
metrics_score(y_train, pred_train_dt)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     17073
#            1       1.00      0.98      0.99      8319
#
#     accuracy                           0.99     25392
#    macro avg       1.00      0.99      0.99     25392
# weighted avg       0.99      0.99      0.99     25392

# %% [markdown]
# **Write your answers here:_____**

# %% [markdown]
# The decision tree model outperformed the other modeling
# methods (regardless of threshold optimization) evaluated thus far as far as accuracy
# metrics with higher levels of precision and recall for both the "Not_Cancelled" and
# "Cancelled" classifications as well as greater overall average accuracy metrics. The
# performance of the model in fitting the test data will help determine if the model is
# overfitting the data or the decision tree is too complex.

# %% [markdown]
# #### Checking model performance on test set

# %%
pred_test_dt = model_dt.predict(X_test)
metrics_score(y_test, pred_test_dt)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90      7317
#            1       0.79      0.80      0.79      3566
#
#     accuracy                           0.86     10883
#    macro avg       0.85      0.85      0.85     10883
# weighted avg       0.86      0.86      0.86     10883

# %% [markdown]
# **Write your answers here:_____**

# %% [markdown]
#  #### **Question 6.3: Perform hyperparameter tuning for the decision tree model using GridSearch CV (1 Mark)**

# %% [markdown]
# **Note: Please use the following hyperparameters provided for tuning the Decision Tree. In general, you can experiment with various hyperparameters to tune the decision tree, but for this project, we recommend sticking to the parameters provided.**

# %%
# Remove _________ and complete the code

# Choose the type of classifier.
estimator =  DecisionTreeClassifier(class_weight = {0: cancel_probs[0], 1:
cancel_probs[1]}, random_state=1)

# Grid of parameters to choose from
parameters = {
    "max_depth": np.arange(2, 7, 2),
    "max_leaf_nodes": [50, 75, 150, 250],
    "min_samples_split": [10, 30, 50, 70],
}


# Run the grid search
grid_obj = GridSearchCV(estimator , parameters)
grid_obj = grid_obj.fit(X_train, y_train)

# Set the clf to the best combination of parameters
estimator = grid_obj.best_estimator_

# Fit the best algorithm to the data.
estimator.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight={0: 0.6723638869745003,
#                                      1: 0.32763611302549966},
#                        max_depth=6, max_leaf_nodes=50, min_samples_split=10,
#                        random_state=1)

# %% [markdown]
# #### **Question 6.4: Check the performance of the model on the train and test data using the tuned model (2 Mark)**

# %% [markdown]
# #### Checking performance on the training set

# %%
# Remove _________ and complete the code

# Checking performance on the training dataset
dt_tuned = estimator.predict(X_train)
metrics_score(y_train, dt_tuned)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.97      0.89     17073
#            1       0.89      0.56      0.69      8319
#
#     accuracy                           0.83     25392
#    macro avg       0.86      0.76      0.79     25392
# weighted avg       0.84      0.83      0.82     25392

# %% [markdown]
# **Write your answers here:_____**

# %% [markdown]
#  The tuned decision tree fit the training data worse than the untuned model but exhibited similar trends in predicting the 'Not_Cancelled' classification better than the 'Cancelled' classification. Though the fitment is less intense than the untuned model, the values do not raise concerns about overfitting. The model's overall performance is similar to the other models except for the recall on the 'Cancelled' classification, which is slightly above 50%.

# %%
# Remove _________ and complete the code

# Checking performance on the training dataset
y_pred_tuned = estimator.predict(X_test)
metrics_score(y_test, y_pred_tuned)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.97      0.89      7317
#            1       0.89      0.56      0.68      3566
#
#     accuracy                           0.83     10883
#    macro avg       0.85      0.76      0.79     10883
# weighted avg       0.84      0.83      0.82     10883

# %% [markdown]
# **Write your answers here:_____**

# %% [markdown]
# The tuned decision tree similarly fits the test data to the training data with comparable overall average accuracy metrics and similar performance predicting each level of classification ('Cancelled' and 'Not_Cancelled'). This indicates that the tuned model is a better overall fit for the dataset and is not overfitting the training data to the detriment of prediction power/accuracy

# %% [markdown]
# #### **Visualizing the Decision Tree**

# %%
feature_names = list(X_train.columns)
plt.figure(figsize=(20, 10))
out = tree.plot_tree(
    estimator,max_depth=3,
    feature_names=feature_names,
    filled=True,
    fontsize=9,
    node_ids=False,
    class_names=None,
)
# below code will add arrows to the decision tree split if they are missing
for o in out:
    arrow = o.arrow_patch
    if arrow is not None:
        arrow.set_edgecolor("black")
        arrow.set_linewidth(1)
plt.show()

# %% [markdown]
# #### **Question 6.5: What are some important features based on the tuned decision tree? (1 Mark)**

# %%
# Remove _________ and complete the code

# Importance of features in the tree building

importances = estimator.feature_importances_
indices = np.argsort(X_train.columns)

plt.figure(figsize=(8, 8))
plt.title("Feature Importances")
plt.barh(range(len(indices)), importances[indices], color="violet", align="center")
plt.yticks(range(len(indices)), [feature_names[i] for i in indices])
plt.xlabel("Relative Importance")
plt.show()

# %% [markdown]
# **Write your answers here:_____**

# %% [markdown]
# Lead time has the highest relative importance, followed by average price per room, market segment type (online), and the number of special requests.

# %% [markdown]
# ___

# %% [markdown]
# ### **Question 7: Random Forest (4 Marks)**

# %% [markdown]
# #### **Question 7.1: Build a Random Forest Model (1 Mark)**

# %%
# Remove _________ and complete the code

rf_estimator = RandomForestClassifier(class_weight = {0: cancel_probs[0], 1: cancel_probs[1]}, random_state = 1)
rf_estimator.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight={0: 0.6723638869745003,
#                                      1: 0.32763611302549966},
#                        random_state=1)

# %% [markdown]
# #### **Question 7.2: Check the performance of the model on the train and test data (2 Marks)**

# %%
# Remove _________ and complete the code

y_pred_train_rf = rf_estimator.predict(X_train)
metrics_score(y_train, y_pred_train_rf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     17073
#            1       1.00      0.98      0.99      8319
#
#     accuracy                           0.99     25392
#    macro avg       1.00      0.99      0.99     25392
# weighted avg       0.99      0.99      0.99     25392

# %% [markdown]
# **Write your answers here:_____**

# %% [markdown]
# The random forest model fits the training data suspiciously well, with near-perfect precision and recall for both the 'Not_Cancelled' and 'Cancelled' classification levels, similar to the un-tuned decision tree that overfit the training data. The accuracy measure values for the random forest model for the training data imply that overfitting is occurring.

# %%
# Remove _________ and complete the code

y_pred_test_rf = rf_estimator.predict(X_test)
metrics_score(y_test, y_pred_test_rf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93      7317
#            1       0.88      0.80      0.84      3566
#
#     accuracy                           0.90     10883
#    macro avg       0.89      0.87      0.88     10883
# weighted avg       0.90      0.90      0.90     10883

# %% [markdown]
# **Write your answers here:_____**

# %% [markdown]
# The random forest model fits the test data with less accuracy than the training data, implying that the model overfits the training data. The testing data accuracy metrics for the 'Not_Cancelled' classification decreased between 5-10% from the training data accuracy metrics, and the 'Cancelled' classification accuracy metrics decreased between 10-20% from the training data accuracy metrics. The overall average accuracy measures for the test data using the random forest model did decrease noticeably from the training data fit. Still, they performed better than several of the previous models.

# %% [markdown]
# #### **Question 7.3: What are some important features based on the Random Forest? (1 Mark)**

# %% [markdown]
# Let's check the feature importance of the Random Forest

# %%
# Remove _________ and complete the code

importances = rf_estimator.feature_importances_
columns = X.columns
importance_df = pd.DataFrame(importances, index = columns, columns = ['Importance']).sort_values(by = 'Importance', ascending = False)

plt.figure(figsize = (13, 13))

sns.barplot(importance_df.Importance, importance_df.index)
# Out:
# <AxesSubplot:xlabel='Importance'>

# %% [markdown]
# **Write your answers here:_____**

# %% [markdown]
#  The random forest model had lead_time as the most critical factor (same as the decision tree model), followed by average price per room, arrival date, # of special requests, and finally, arrival month. Though the list of the essential factors is different from the list of important factors from the decision tree model, I am more inclined to recommend the random forest model as it had the best fit for the test data (higher overall average accuracy metrics) than any of the other models, regardless of the marked decrease between the random forest metrics for the training data vs. the test data.

# %% [markdown]
# ### **Question 8: Conclude ANY FOUR key takeaways for business recommendations (4 Marks)**

# %% [markdown]
# **Write your answers here:_____**

# %% [markdown]
# 1.) I recommend using the random forest model for cancellation prediction. Although the model showed signs of overfitting the training data, the overall average accuracy metrics for the test data were better than the other models evaluated. 2.) Both false positive (flagging a booking for cancellation when it is not) and false negative (flagging a booking as not likely to be canceled when it is canceled) misclassifications have the potential to impact the hotel negatively. Any future planning or operational changes should be undertaken to balance the overall precision and recall of both predictive ability for recognizing potential 'Not_Cancelled' and 'Cancelled' booking 3.) Lead time seems essential in classifying the data into the 'Cancelled' and 'Not_Cancelled' groups. Operational changes that minimize the negative impacts of booking misclassifications will likely use the lead time of the individual booking as an independent variable. 4.) Certain market types are generally safe assumptions, particularly for the 'Not_Cancelled' classification (Corporate, Complementary market types have minimal cancellations compared to Online or Aviation bookings), possibly due to the demographic characteristics and general scheduling consistency between the market type cohorts. Therefore, certain market-type

# %% [markdown]
# ## **Happy Learning!**

# %%
# %%shell
# jupyter nbconvert --to html //Your notebook path Shakiba_Mashini.ipynb
# Out:
# [NbConvertApp] WARNING | pattern '//Your' matched no files
# [NbConvertApp] WARNING | pattern 'notebook' matched no files
# [NbConvertApp] WARNING | pattern 'path' matched no files
# [NbConvertApp] Converting notebook Shakiba_Mashini.ipynb to html
# [NbConvertApp] Writing 1904740 bytes to Shakiba_Mashini.html
